# %%
import pandas as pd

df = pd.read_excel("Test_Production_Data_Excel 1.xlsx")
df
# Out:
#         CASE_ID  AGENT ID POLICYNUMBER   License         Agent Full Name  \
# 0      31558089   9811878     46384999  Approved              Hu, Philip
# 1      31558089  23289898     46384999  Approved             Xu, Weitong
# 2      31536732  22343654     71956124  Approved             Hoang, Wing
# 3      30867214  21647041     1182358X  Inactive          Kang, Sunghoon
# 4      31851780  18704542     60193418  Approved                Yu, Ying
# ...         ...       ...          ...       ...                     ...
# 16816  32157475  20829454   ST11483589  Approved             Zhu, Wenyan
# 16817  32166578  19796365     60198984  Approved               Xu, Jenny
# 16818  32185106  18559459   US70027112  Approved  Srirattana, Rattanapol
# 16819  32185118  18559459   US70027111  Approved  Srirattana, Rattanapol
# 16820  32185354  20917481     46408929  Approved    Yang, Julia Xiaohong
#
#          Year Quarter     Month  Unnamed: 8   Day  ...  \
# ...

# %%
df.columns
# Out:
# Index(['CASE_ID', 'AGENT ID', 'POLICYNUMBER', 'License', 'Agent Full Name',
#        'Year', 'Quarter', 'Month', 'Unnamed: 8', 'Day', 'Date', 'PERCENT',
#        'Region %', 'Sum of MODE_PREMIUM', 'Actual Mode Premium Measure',
#        'Sum of TARGET_PREMIUM', 'Actual Target Premium Measure', 'CODE_NAME',
#        'Region', 'Split 1', 'Split 2', 'Split 3', 'Split 4', 'Split 5',
#        'PRODUCT_CHANNEL', 'CARRIER_NAME', 'PRODUCT_NAME',
#        'ENTITY_STATUS_DESCRIPTION', 'APPLICATION_STATUS', 'Direct Upline',
#        'Agent Director', 'EMAIL_PRM_ADDRESS', 'Unnamed: 32', 'CASE_ID.1',
#        'AGENT ID.1', 'POLICYNUMBER.1', 'License.1', 'Agent Full Name.1',
#        'Year.1', 'Quarter.1', 'Month.1', 'Day.1', 'PERCENT.1', 'Region %.1',
#        'Sum of MODE_PREMIUM.1', 'Actual Mode Premium Measure.1',
#        'Sum of TARGET_PREMIUM.1', 'Actual Target Premium Measure.1',
#        'CODE_NAME.1', 'Region.1', 'Split 1.1', 'Split 2.1', 'Split 3.1',
# ...

# %%
df_filtered = df[['POLICYNUMBER']]
len(df_filtered)
# Out:
# 16821
